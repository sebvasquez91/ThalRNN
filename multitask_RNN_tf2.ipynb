# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# False

# %%
import train
import time

start = time.time()

tf.compat.v1.disable_eager_execution()
train.train(model_dir='debug', hp={'learning_rate': 0.001}, ruleset='mante')

end = time.time()
print(end - start)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 18:55:55.946954 4447909312 deprecation.py:506] From /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:175: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0127 18:55:55.947911 4447909312 deprecation.py:323] From /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:569: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0127 18:55:56.001926 4447909312 deprecation.py:323] From /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:195: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0127 18:55:56.013607 4447909312 deprecation.py:506] From /Users/svasquez91/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# W0127 18:55:56.014925 4447909312 deprecation.py:506] From /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:199: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(323, 256) dtype=float32>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32>
# <tf.Variable 'output/weights:0' shape=(256, 33) dtype=float32>
# <tf.Variable 'output/biases:0' shape=(33,) dtype=float32>
# batch_size_train     = 64
# batch_size_test      = 512
# in_type              = normal
# rnn_type             = LeakyRNN
# use_separate_input   = False
# loss_type            = lsq
# optimizer            = adam
# activation           = relu
# tau                  = 100
# dt                   = 20
# alpha                = 0.2
# sigma_rec            = 0.05
# sigma_x              = 0.01
# w_rec_init           = randortho
# l1_h                 = 0
# l2_h                 = 0
# l1_weight            = 0
# l2_weight            = 0
# l2_weight_init       = 0
# p_weight_train       = None
# target_perf          = 1.0
# n_eachring           = 32
# num_ring             = 2
# n_rule               = 2
# rule_start           = 65
# n_input              = 67
# n_output             = 33
# n_rnn                = 256
# ruleset              = mante
# save_name            = test
# learning_rate        = 0.001
# c_intsyn             = 0
# ksi_intsyn           = 0
# seed                 = 0
# rng                  = <mtrand.RandomState object at 0xb2feb28c0>
# rule_trains          = ['contextdm1', 'contextdm2']
# rules                = ['contextdm1', 'contextdm2']
# rule_probs           = [0.5, 0.5]
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(323, 256) dtype=float32>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32>
# <tf.Variable 'output/weights:0' shape=(256, 33) dtype=float32>
# <tf.Variable 'output/biases:0' shape=(33,) dtype=float32>
# Trial       0  | Time 0.39 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.275165| c_reg 0.000000  | perf 0.01
# contextdm2     | cost 1.530045| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial   32000  | Time 66.74 s  | Now training contextdm1 & contextdm2
# /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:40: RuntimeWarning: invalid value encountered in true_divide
#   temp_cos = np.sum(y*np.cos(pref), axis=-1)/temp_sum
# /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:41: RuntimeWarning: invalid value encountered in true_divide
#   temp_sin = np.sum(y*np.sin(pref), axis=-1)/temp_sum
# /Users/svasquez91/My_scripts_Local/Models_Local/multitask_RNN_tf2/network.py:86: RuntimeWarning: invalid value encountered in less
#   corr_loc = dist < 0.2*np.pi
# contextdm1     | cost 1.329266| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.276515| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial   64000  | Time 146.21 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.260804| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.185011| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial   96000  | Time 213.15 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.356012| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.328205| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  128000  | Time 278.91 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.245473| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.254922| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  160000  | Time 342.63 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.142077| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.372943| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  192000  | Time 409.26 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.344811| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.238196| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  224000  | Time 476.98 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.263278| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.367544| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  256000  | Time 540.27 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.250824| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.185116| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  288000  | Time 602.43 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.411708| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.475213| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  320000  | Time 663.11 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.202477| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.208845| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  352000  | Time 728.06 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 1.342712| c_reg 0.000000  | perf 0.00
# contextdm2     | cost 1.378948| c_reg 0.000000  | perf 0.00
# Model saved in file: debug/model.ckpt
# Trial  384000  | Time 790.63 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.352624| c_reg 0.000000  | perf 0.22
# contextdm2     | cost 0.331860| c_reg 0.000000  | perf 0.17
# Model saved in file: debug/model.ckpt
# Trial  416000  | Time 856.08 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.195895| c_reg 0.000000  | perf 0.20
# contextdm2     | cost 0.225177| c_reg 0.000000  | perf 0.14
# Model saved in file: debug/model.ckpt
# Trial  448000  | Time 927.62 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.178940| c_reg 0.000000  | perf 0.57
# contextdm2     | cost 0.238201| c_reg 0.000000  | perf 0.47
# Model saved in file: debug/model.ckpt
# Trial  480000  | Time 994.45 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.178815| c_reg 0.000000  | perf 0.65
# contextdm2     | cost 0.184569| c_reg 0.000000  | perf 0.61
# Model saved in file: debug/model.ckpt
# Trial  512000  | Time 1057.56 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.155258| c_reg 0.000000  | perf 0.67
# contextdm2     | cost 0.179932| c_reg 0.000000  | perf 0.56
# Model saved in file: debug/model.ckpt
# Trial  544000  | Time 1120.73 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.149741| c_reg 0.000000  | perf 0.66
# contextdm2     | cost 0.198628| c_reg 0.000000  | perf 0.59
# Model saved in file: debug/model.ckpt
# Trial  576000  | Time 1184.02 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.179571| c_reg 0.000000  | perf 0.64
# contextdm2     | cost 0.190021| c_reg 0.000000  | perf 0.58
# Model saved in file: debug/model.ckpt
# Trial  608000  | Time 1246.21 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.137083| c_reg 0.000000  | perf 0.67
# contextdm2     | cost 0.173823| c_reg 0.000000  | perf 0.64
# Model saved in file: debug/model.ckpt
# Trial  640000  | Time 1310.28 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.158915| c_reg 0.000000  | perf 0.71
# contextdm2     | cost 0.117347| c_reg 0.000000  | perf 0.77
# Model saved in file: debug/model.ckpt
# Trial  672000  | Time 1374.79 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.137227| c_reg 0.000000  | perf 0.75
# contextdm2     | cost 0.136682| c_reg 0.000000  | perf 0.73
# Model saved in file: debug/model.ckpt
# Trial  704000  | Time 1436.95 s  | Now training contextdm1 & contextdm2
# contextdm1     | cost 0.142614| c_reg 0.000000  | perf 0.77
# contextdm2     | cost 0.091167| c_reg 0.000000  | perf 0.83
# Model saved in file: debug/model.ckpt

# %%
# !tf_upgrade_v2 \
    --intree v1_4/ \
    --outtree v2_0/ \
    --reportfile tree_report.txt
# Out:
# INFO line 53:15: Added keywords to args of function 'tf.reduce_sum'
# INFO line 54:15: Added keywords to args of function 'tf.reduce_sum'
# INFO line 55:15: Added keywords to args of function 'tf.reduce_sum'
# INFO line 57:11: Renamed 'tf.mod' to 'tf.math.mod'
# INFO line 175:28: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 175:28: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 210:16: Renamed 'tf.random_normal' to 'tf.random.normal'
# INFO line 210:33: Added keywords to args of function 'tf.shape'
# INFO line 317:19: Renamed 'tf.random_normal' to 'tf.random.normal'
# INFO line 317:36: Added keywords to args of function 'tf.shape'
# INFO line 390:28: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 390:28: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 419:16: Renamed 'tf.random_normal' to 'tf.random.normal'
# INFO line 419:33: Added keywords to args of function 'tf.shape'
# INFO line 448:8: Renamed 'tf.reset_default_graph' to 'tf.compat.v1.reset_default_graph'
# INFO line 456:8: Renamed 'tf.set_random_seed' to 'tf.compat.v1.set_random_seed'
# INFO line 485:24: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 496:29: Added keywords to args of function 'tf.reduce_mean'
# INFO line 502:17: Added keywords to args of function 'tf.reduce_mean'
# INFO line 509:23: Renamed 'tf.train.AdamOptimizer' to 'tf.compat.v1.train.AdamOptimizer'
# INFO line 512:23: Renamed 'tf.train.GradientDescentOptimizer' to 'tf.compat.v1.train.GradientDescentOptimizer'
# INFO line 519:21: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 526:17: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 527:17: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 529:26: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 532:26: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 558:19: Renamed 'tf.contrib.rnn.LSTMCell' to 'tf.compat.v1.nn.rnn_cell.LSTMCell'
# INFO line 561:19: Renamed 'tf.contrib.rnn.GRUCell' to 'tf.compat.v1.nn.rnn_cell.GRUCell'
# INFO line 572:13: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# WARNING line 574:20: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# INFO line 574:20: Renamed 'tf.get_variable' to 'tf.compat.v1.get_variable'
# WARNING line 579:20: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# INFO line 579:20: Renamed 'tf.get_variable' to 'tf.compat.v1.get_variable'
# INFO line 583:28: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 583:28: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 593:28: Added keywords to args of function 'tf.reduce_mean'
# INFO line 598:28: Added keywords to args of function 'tf.reduce_mean'
# INFO line 599:30: Changing labels arg of tf.nn.softmax_cross_entropy_with_logits to tf.stop_gradient(labels). Please check this transformation.
#
# INFO line 603:37: Added keywords to args of function 'tf.shape'
# INFO line 650:17: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 651:17: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 652:22: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 657:29: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 661:33: tf.orthogonal_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 661:33: Renamed 'tf.orthogonal_initializer' to 'tf.compat.v1.orthogonal_initializer'
# INFO line 662:26: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 667:26: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 687:16: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 690:24: Added keywords to args of function 'tf.reduce_mean'
# INFO line 694:37: Added keywords to args of function 'tf.shape'
# INFO line 745:15: Renamed 'tf.get_default_session' to 'tf.compat.v1.get_default_session'
# INFO line 746:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 750:15: Renamed 'tf.get_default_session' to 'tf.compat.v1.get_default_session'
# INFO line 758:25: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 764:15: Renamed 'tf.get_default_session' to 'tf.compat.v1.get_default_session'
# WARNING line 766:8: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# WARNING line 166:4: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 259:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 264:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 295:34: Added keywords to args of function 'tf.size'
# INFO line 398:17: Added keywords to args of function 'tf.gradients'
# INFO line 411:26: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 412:12: tf.summary.histogram requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 412:12: Renamed 'tf.summary.histogram' to 'tf.compat.v1.summary.histogram'
# INFO line 414:13: tf.summary.merge_all requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 414:13: Renamed 'tf.summary.merge_all' to 'tf.compat.v1.summary.merge_all'
# INFO line 415:18: tf.summary.FileWriter requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 415:18: Renamed 'tf.summary.FileWriter' to 'tf.compat.v1.summary.FileWriter'
# INFO line 421:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 422:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 455:42: Added keywords to args of function 'tf.reduce_sum'
# INFO line 578:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 579:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 376:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 479:17: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 120:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 185:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 263:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 521:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 570:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 47:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 276:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 483:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 25:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 50:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 92:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 222:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 300:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 337:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 484:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 106:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 309:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 633:9: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 27:13: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 297:17: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# TensorFlow 2.0 Upgrade Script
# -----------------------------
# Converted 21 files
# Detected 4 issues that require attention
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# File: v1_4/network.py
# --------------------------------------------------------------------------------
# v1_4/network.py:574:20: WARNING: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# v1_4/network.py:579:20: WARNING: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# v1_4/network.py:766:8: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# --------------------------------------------------------------------------------
# File: v1_4/train.py
# --------------------------------------------------------------------------------
# v1_4/train.py:166:4: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
#
#
# Make sure to read the detailed log 'tree_report.txt'
